# %%
import pandas as pd
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
# some information:
# pclass: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower

# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5

# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)

# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %%
df = pd.read_csv('train.csv')
df2 = df
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# check NaN
df2.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
# delete ticket and cabin and embarked
df2.drop(columns=['Ticket','Cabin','Embarked','Name'],inplace=True)

# %%
# change Sec into index
# male = 0 and female = 1
df2.replace('male',0,inplace=True)
df2.replace('female',1,inplace=True)

# %%
# add median to NaN in column   28
df2['Age'].fillna(df2['Age'].median(),inplace=True)

# %%
# add median to NaN in column Fare  
df2['Fare'].fillna(df2['Fare'].median(),inplace=True)

# %%
# concat SibSp and Parch into one column Family
df2['family'] = df2['SibSp']+df2['Parch']
df2.drop(columns=['SibSp','Parch'],inplace=True)

# %%
df3 = df2.drop(columns=['Survived'])

# %%
# divide into train and test dataset
Xtrain,Xtest,Ytrain,Ytest = train_test_split(df3,df2['Survived'])

# %%
# A very simple decision Tree prediction
clf = tree.DecisionTreeClassifier(criterion="entropy")
clf = clf.fit(Xtrain,Ytrain)
score = clf.score(Xtest,Ytest)
score
# Out:
# 0.7488789237668162
